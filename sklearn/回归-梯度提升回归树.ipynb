# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
boston = load_boston()

# %%
data = boston.data
target = boston.target

# %%
names = boston.feature_names

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.33, random_state=42)

# %%
line_model = GradientBoostingRegressor().fit(X_train,y_train)

# %%
line_model
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = line_model.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([22.96787001, 31.44494275, 16.20393151, 23.70328738, 17.49686625,
#        22.17055683, 18.5346168 , 14.14453957, 20.70497822, 21.04457326])

# %%
y_test[:10]
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8])

# %% [markdown]
# # 回归结果可视化

# %%
import matplotlib.pyplot as ply

# %%
from matplotlib import rcParams

# %%
rcParams['font.sans-serif'] = "SimHei"

# %%
fig = ply.figure(figsize=(10,6))

# %%
ply.plot(range(y_test.shape[0]),y_test,color='blue',linewidth=1.5,linestyle='-')
ply.plot(range(y_test.shape[0]),y_pred,color='red',linewidth=1.5,linestyle='-')
ply.xlim(0,102)
ply.ylim(0,55)
ply.legend(['real value','predict value'])
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error ,median_absolute_error,explained_variance_score,r2_score

# %%
method = [mean_absolute_error,mean_squared_error ,median_absolute_error,explained_variance_score,r2_score]

# %%
for i in method:
    print(i.__name__,i(y_test,y_pred))
# Out:
# mean_absolute_error 1.9823883238752473
# mean_squared_error 8.46226330748505
# median_absolute_error 1.2953816515941696
# explained_variance_score 0.888602383983065
# r2_score 0.8881814204656988
